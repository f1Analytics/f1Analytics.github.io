# %%
import fastf1 as ff1
from fastf1 import plotting

import pandas as pd

from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
from matplotlib import cm

import numpy as np

import os
import sys

# Enable the cache
#ff1.Cache.enable_cache('cache/') 

# Get rid of an error
pd.options.mode.chained_assignment = None

year, grand_prix, session = int(2023), 'azerbaijan', 'R'

circuit = grand_prix.replace(" ", "_")
foldername = f"assets/img/{year}/{circuit}/"

if not os.path.exists(foldername):
    os.makedirs(foldername)

# Load the session data
race = ff1.get_session(year, circuit, session)

# Get the laps
laps = race.load_laps()

# Convert laptimes to seconds
laps['LapTimeSeconds'] = laps['LapTime'].dt.total_seconds()

# To get accurate laps only, we exclude in- and outlaps
laps = laps.loc[(laps['PitOutTime'].isnull() & laps['PitInTime'].isnull())]

# Also, we remove outliers since those don't represent the racepace,
# using the Inter-Quartile Range (IQR) proximity rule
q75, q25 = laps['LapTimeSeconds'].quantile(0.75), laps['LapTimeSeconds'].quantile(0.25)

intr_qr = q75 - q25

laptime_max = q75 + (1.5 * intr_qr) # IQR proximity rule: Max = q75 + 1,5 * IQR
laptime_min = q25 - (1.5 * intr_qr) # IQR proximity rule: Min = q25 + 1,5 * IQR

laps.loc[laps['LapTimeSeconds'] < laptime_min, 'LapTimeSeconds'] = np.nan
laps.loc[laps['LapTimeSeconds'] > laptime_max, 'LapTimeSeconds'] = np.nan

# drivers_to_visualize = [i for i in sys.argv[3:]]
drivers_to_visualize = ['LEC', 'PER', 'VER', 'ALO', 'HAM']

# To make sure we won't get any equally styled lines when comparing teammates
visualized_teams = []

# Make plot a bit bigger
plt.rcParams['figure.figsize'] = [10, 10]

# Create 2 subplots (1 for the boxplot, 1 for the lap-by-lap comparison)
fig, ax = plt.subplots(2)
# Out:
# /Users/epillon/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:1220: FutureWarning: `Session.load_laps` is deprecated and will beremoved in a future version.
# Use `Session.load` instead.
#   warnings.warn("`Session.load_laps` is deprecated and will be"
# core           INFO 	Loading data for Azerbaijan Grand Prix - Race [v2.3.0]
# api            INFO 	Fetching driver list...
# api            INFO 	Fetching timing data...
# api            INFO 	Parsing timing data...
# api            INFO 	Fetching timing app data...
# core           INFO 	Processing timing data...
# api            INFO 	Fetching session status data...
# api            INFO 	Fetching track status data...
# /Users/epillon/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:1415: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /Users/epillon/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:1415: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /Users/epillon/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:1415: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /Users/epillon/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:1415: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /Users/epillon/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:1415: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /Users/epillon/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:1415: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /Users/epillon/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:1415: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /Users/epillon/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:1415: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /Users/epillon/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:1415: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /Users/epillon/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:1415: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /Users/epillon/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:1415: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /Users/epillon/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:1415: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /Users/epillon/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:1415: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /Users/epillon/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:1415: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /Users/epillon/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:1415: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /Users/epillon/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:1415: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /Users/epillon/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:1415: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /Users/epillon/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:1415: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /Users/epillon/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:1415: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# api            INFO 	Fetching weather data...
# api            INFO 	Fetching race control messages...
# core           INFO 	Finished loading data for 20 drivers: ['11', '1', '16', '14', '55', '44', '18', '63', '4', '22', '81', '23', '20', '10', '31', '2', '27', '77', '24', '21']

# %%
laptimes = [laps.pick_driver(x)['LapTimeSeconds'].dropna() for x in drivers_to_visualize] 

# ax[0].boxplot(laptimes, labels=drivers_to_visualize)

# %%
plt.boxplot(laptimes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 plt.boxplot(laptimes)
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/pyplot.py:2437, in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, data)
#    2427 @docstring.copy(Axes.boxplot)
#    2428 def boxplot(
#    2429         x, notch=None, sym=None, vert=None, whis=None,
#    (...)
#    2435         whiskerprops=None, manage_ticks=True, autorange=False,
#    2436         zorder=None, *, data=None):
# -> 2437     return gca().boxplot(
#    2438         x, notch=notch, sym=sym, vert=vert, whis=whis,
#    2439         positions=positions, widths=widths, patch_artist=patch_artist,
#    2440         bootstrap=bootstrap, usermedians=usermedians,
#    2441         conf_intervals=conf_intervals, meanline=meanline,
#    2442         showmeans=showmeans, showcaps=showcaps, showbox=showbox,
#    2443         showfliers=showfliers, boxprops=boxprops, labels=labels,
#    2444         flierprops=flierprops, medianprops=medianprops,
#    2445         meanprops=meanprops, capprops=capprops,
#    2446         whiskerprops=whiskerprops, manage_ticks=manage_ticks,
#    2447         autorange=autorange, zorder=zorder, **({"data": data} if data
#    2448         is not None else {}))
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/cbook/deprecation.py:296, in _rename_parameter.<locals>.wrapper(*args, **kwargs)
#     291     warn_deprecated(
#     292         since, message=f"The {old!r} parameter of {func.__name__}() "
#     293         f"has been renamed {new!r} since Matplotlib {since}; support "
#     294         f"for the old name will be dropped %(removal)s.")
#     295     kwargs[new] = kwargs.pop(old)
# --> 296 return func(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/__init__.py:1543, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1540 @functools.wraps(func)
#    1541 def inner(ax, *args, data=None, **kwargs):
#    1542     if data is None:
# -> 1543         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1545     bound = new_sig.bind(ax, *args, **kwargs)
#    1546     auto_label = (bound.arguments.get(label_namer)
#    1547                   or bound.kwargs.get(label_namer))
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/axes/_axes.py:3626, in Axes.boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder)
#    3623 if bootstrap is None:
#    3624     bootstrap = rcParams['boxplot.bootstrap']
# -> 3626 bxpstats = cbook.boxplot_stats(x, whis=whis, bootstrap=bootstrap,
#    3627                                labels=labels, autorange=autorange)
#    3628 if notch is None:
#    3629     notch = rcParams['boxplot.notch']
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/cbook/__init__.py:1165, in boxplot_stats(X, whis, bootstrap, labels, autorange)
#    1162 bxpstats = []
#    1164 # convert X to a list of lists
# -> 1165 X = _reshape_2D(X, "X")
#    1167 ncols = len(X)
#    1168 if labels is None:
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/cbook/__init__.py:1376, in _reshape_2D(X, name)
#    1365 """
#    1366 Use Fortran ordering to convert ndarrays and lists of iterables to lists of
#    1367 1D arrays.
#    (...)
#    1373 *name* is used to generate the error message for invalid inputs.
#    1374 """
#    1375 # Iterate over columns for ndarrays, over rows otherwise.
# -> 1376 X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
#    1377 if len(X) == 0:
#    1378     return [[]]
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (5,) + inhomogeneous part.

# %%
len(laptimes[0])
# Out:
# 47

# %%
plt.boxplot(laptimes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 plt.boxplot(laptimes)
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/pyplot.py:2437, in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, data)
#    2427 @docstring.copy(Axes.boxplot)
#    2428 def boxplot(
#    2429         x, notch=None, sym=None, vert=None, whis=None,
#    (...)
#    2435         whiskerprops=None, manage_ticks=True, autorange=False,
#    2436         zorder=None, *, data=None):
# -> 2437     return gca().boxplot(
#    2438         x, notch=notch, sym=sym, vert=vert, whis=whis,
#    2439         positions=positions, widths=widths, patch_artist=patch_artist,
#    2440         bootstrap=bootstrap, usermedians=usermedians,
#    2441         conf_intervals=conf_intervals, meanline=meanline,
#    2442         showmeans=showmeans, showcaps=showcaps, showbox=showbox,
#    2443         showfliers=showfliers, boxprops=boxprops, labels=labels,
#    2444         flierprops=flierprops, medianprops=medianprops,
#    2445         meanprops=meanprops, capprops=capprops,
#    2446         whiskerprops=whiskerprops, manage_ticks=manage_ticks,
#    2447         autorange=autorange, zorder=zorder, **({"data": data} if data
#    2448         is not None else {}))
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/cbook/deprecation.py:296, in _rename_parameter.<locals>.wrapper(*args, **kwargs)
#     291     warn_deprecated(
#     292         since, message=f"The {old!r} parameter of {func.__name__}() "
#     293         f"has been renamed {new!r} since Matplotlib {since}; support "
#     294         f"for the old name will be dropped %(removal)s.")
#     295     kwargs[new] = kwargs.pop(old)
# --> 296 return func(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/__init__.py:1543, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1540 @functools.wraps(func)
#    1541 def inner(ax, *args, data=None, **kwargs):
#    1542     if data is None:
# -> 1543         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1545     bound = new_sig.bind(ax, *args, **kwargs)
#    1546     auto_label = (bound.arguments.get(label_namer)
#    1547                   or bound.kwargs.get(label_namer))
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/axes/_axes.py:3626, in Axes.boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder)
#    3623 if bootstrap is None:
#    3624     bootstrap = rcParams['boxplot.bootstrap']
# -> 3626 bxpstats = cbook.boxplot_stats(x, whis=whis, bootstrap=bootstrap,
#    3627                                labels=labels, autorange=autorange)
#    3628 if notch is None:
#    3629     notch = rcParams['boxplot.notch']
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/cbook/__init__.py:1165, in boxplot_stats(X, whis, bootstrap, labels, autorange)
#    1162 bxpstats = []
#    1164 # convert X to a list of lists
# -> 1165 X = _reshape_2D(X, "X")
#    1167 ncols = len(X)
#    1168 if labels is None:
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/cbook/__init__.py:1376, in _reshape_2D(X, name)
#    1365 """
#    1366 Use Fortran ordering to convert ndarrays and lists of iterables to lists of
#    1367 1D arrays.
#    (...)
#    1373 *name* is used to generate the error message for invalid inputs.
#    1374 """
#    1375 # Iterate over columns for ndarrays, over rows otherwise.
# -> 1376 X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
#    1377 if len(X) == 0:
#    1378     return [[]]
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (5,) + inhomogeneous part.

# %%
for i in laptimes:
    print(len(i))
# Out:
# 47
# 47
# 46
# 47
# 45

# %%
new_laptimes = [laptimes[1], laptimes[0], laptimes[3], laptimes[2]]
plt.boxplot(new_laptimes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 2
#       1 new_laptimes = [laptimes[1], laptimes[0], laptimes[3], laptimes[2]]
# ----> 2 plt.boxplot(new_laptimes)
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/pyplot.py:2437, in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, data)
#    2427 @docstring.copy(Axes.boxplot)
#    2428 def boxplot(
#    2429         x, notch=None, sym=None, vert=None, whis=None,
#    (...)
#    2435         whiskerprops=None, manage_ticks=True, autorange=False,
#    2436         zorder=None, *, data=None):
# -> 2437     return gca().boxplot(
#    2438         x, notch=notch, sym=sym, vert=vert, whis=whis,
#    2439         positions=positions, widths=widths, patch_artist=patch_artist,
#    2440         bootstrap=bootstrap, usermedians=usermedians,
#    2441         conf_intervals=conf_intervals, meanline=meanline,
#    2442         showmeans=showmeans, showcaps=showcaps, showbox=showbox,
#    2443         showfliers=showfliers, boxprops=boxprops, labels=labels,
#    2444         flierprops=flierprops, medianprops=medianprops,
#    2445         meanprops=meanprops, capprops=capprops,
#    2446         whiskerprops=whiskerprops, manage_ticks=manage_ticks,
#    2447         autorange=autorange, zorder=zorder, **({"data": data} if data
#    2448         is not None else {}))
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/cbook/deprecation.py:296, in _rename_parameter.<locals>.wrapper(*args, **kwargs)
#     291     warn_deprecated(
#     292         since, message=f"The {old!r} parameter of {func.__name__}() "
#     293         f"has been renamed {new!r} since Matplotlib {since}; support "
#     294         f"for the old name will be dropped %(removal)s.")
#     295     kwargs[new] = kwargs.pop(old)
# --> 296 return func(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/__init__.py:1543, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1540 @functools.wraps(func)
#    1541 def inner(ax, *args, data=None, **kwargs):
#    1542     if data is None:
# -> 1543         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1545     bound = new_sig.bind(ax, *args, **kwargs)
#    1546     auto_label = (bound.arguments.get(label_namer)
#    1547                   or bound.kwargs.get(label_namer))
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/axes/_axes.py:3626, in Axes.boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder)
#    3623 if bootstrap is None:
#    3624     bootstrap = rcParams['boxplot.bootstrap']
# -> 3626 bxpstats = cbook.boxplot_stats(x, whis=whis, bootstrap=bootstrap,
#    3627                                labels=labels, autorange=autorange)
#    3628 if notch is None:
#    3629     notch = rcParams['boxplot.notch']
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/cbook/__init__.py:1165, in boxplot_stats(X, whis, bootstrap, labels, autorange)
#    1162 bxpstats = []
#    1164 # convert X to a list of lists
# -> 1165 X = _reshape_2D(X, "X")
#    1167 ncols = len(X)
#    1168 if labels is None:
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/cbook/__init__.py:1376, in _reshape_2D(X, name)
#    1365 """
#    1366 Use Fortran ordering to convert ndarrays and lists of iterables to lists of
#    1367 1D arrays.
#    (...)
#    1373 *name* is used to generate the error message for invalid inputs.
#    1374 """
#    1375 # Iterate over columns for ndarrays, over rows otherwise.
# -> 1376 X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
#    1377 if len(X) == 0:
#    1378     return [[]]
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (4,) + inhomogeneous part.
