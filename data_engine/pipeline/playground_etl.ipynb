# %%
import fastf1 as ff1

year, gp_id = 2024, 3

quali = ff1.get_session(year, gp_id, "Q")
quali.load(weather=False)
# Out:
# core           INFO 	Loading data for Australian Grand Prix - Qualifying [v3.3.1]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 19 drivers: ['1', '55', '11', '4', '16', '81', '63', '22', '18', '14', '44', '23', '77', '20', '31', '27', '10', '3', '24']

# %%
import os
def save_retrieved_data(data, data_type, year, gp_id):
    path = f"retrieved_data/{year}/{gp_id}/"
    os.makedirs(path, exist_ok=True)
    data.to_csv(path+data_type+".csv", index=False)

# %%
save_retrieved_data(quali.results, "results", year, gp_id)

# %%
for driver in quali.drivers:
    abbr = quali.get_driver(driver)["Abbreviation"]
    telemetry = quali.laps.pick_driver("VER").pick_fastest().get_telemetry()
    save_retrieved_data(telemetry, f"telemetry_{abbr}", year, gp_id)
# Out:
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.

# %%
quali.laps
# Out:
#                       Time Driver DriverNumber                LapTime  \
# 0   0 days 00:17:56.176000    VER            1 0 days 00:01:40.765000
# 1   0 days 00:19:13.654000    VER            1 0 days 00:01:17.478000
# 2   0 days 00:21:48.125000    VER            1                    NaT
# 3   0 days 00:23:28.134000    VER            1 0 days 00:01:40.009000
# 4   0 days 00:24:45.363000    VER            1 0 days 00:01:17.229000
# ..                     ...    ...          ...                    ...
# 305 0 days 00:24:09.375000    ZHO           24 0 days 00:01:18.188000
# 306 0 days 00:29:48.193000    ZHO           24                    NaT
# 307 0 days 00:31:42.067000    ZHO           24 0 days 00:01:53.874000
# 308 0 days 00:33:00.502000    ZHO           24 0 days 00:01:18.435000
# 309 0 days 00:34:46.396000    ZHO           24                    NaT
#
#      LapNumber  Stint             PitOutTime              PitInTime  \
# 0          1.0    1.0 0 days 00:16:20.464000                    NaT
# 1          2.0    1.0                    NaT                    NaT
# 2          3.0    1.0                    NaT 0 days 00:20:59.534000
# 3          4.0    2.0 0 days 00:21:50.135000                    NaT
# 4          5.0    2.0                    NaT                    NaT
# ..         ...    ...                    ...                    ...
# 305        5.0    1.0                    NaT                    NaT
# 306        6.0    1.0                    NaT 0 days 00:25:47.213000
# 307        7.0    2.0 0 days 00:29:58.954000                    NaT
# 308        8.0    2.0                    NaT                    NaT
# 309        9.0    2.0                    NaT 0 days 00:34:46.396000
#
#                Sector1Time            Sector2Time  ... FreshTyre  \
# 0   0 days 00:00:46.124000 0 days 00:00:19.167000  ...      True
# 1   0 days 00:00:26.827000 0 days 00:00:17.500000  ...      True
# 2   0 days 00:00:37.806000 0 days 00:00:26.028000  ...      True
# 3   0 days 00:00:38.811000 0 days 00:00:23.459000  ...     False
# 4   0 days 00:00:26.591000 0 days 00:00:17.522000  ...     False
# ..                     ...                    ...  ...       ...
# 305 0 days 00:00:26.991000 0 days 00:00:17.944000  ...      True
# 306 0 days 00:00:34.337000 0 days 00:00:24.738000  ...      True
# 307 0 days 00:00:50.888000 0 days 00:00:18.747000  ...      True
# 308 0 days 00:00:26.788000 0 days 00:00:17.706000  ...      True
# 309 0 days 00:00:36.181000 0 days 00:00:24.106000  ...      True
#
#                 Team           LapStartTime            LapStartDate  \
# 0    Red Bull Racing 0 days 00:16:20.464000 2024-03-23 05:01:21.852
# 1    Red Bull Racing 0 days 00:17:56.176000 2024-03-23 05:02:57.564
# 2    Red Bull Racing 0 days 00:19:13.654000 2024-03-23 05:04:15.042
# 3    Red Bull Racing 0 days 00:21:48.125000 2024-03-23 05:06:49.513
# 4    Red Bull Racing 0 days 00:23:28.134000 2024-03-23 05:08:29.522
# ..               ...                    ...                     ...
# 305      Kick Sauber 0 days 00:22:51.187000 2024-03-23 05:07:52.575
# 306      Kick Sauber 0 days 00:24:09.375000 2024-03-23 05:09:10.763
# 307      Kick Sauber 0 days 00:29:48.193000 2024-03-23 05:14:49.581
# 308      Kick Sauber 0 days 00:31:42.067000 2024-03-23 05:16:43.455
# 309      Kick Sauber 0 days 00:33:00.502000 2024-03-23 05:18:01.890
#
#      TrackStatus  Position  Deleted  DeletedReason  FastF1Generated IsAccurate
# 0              1       NaN    False                           False      False
# 1              1       NaN    False                           False       True
# 2              1       NaN    False                           False      False
# 3              1       NaN    False                           False      False
# 4              1       NaN    False                           False       True
# ..           ...       ...      ...            ...              ...        ...
# 305            1       NaN    False                           False       True
# 306            1       NaN    False                           False      False
# 307            1       NaN    False                           False      False
# 308            1       NaN    False                           False       True
# 309            1       NaN    False                           False      False
#
# [310 rows x 31 columns]

# %%
race = ff1.get_session(year, gp_id, "R")
race.load(weather=False, telemetry=False)


race_laps = race.laps
save_retrieved_data(race_laps, "racelaps", year, gp_id)
# Out:
# core           INFO 	Loading data for Australian Grand Prix - Race [v3.3.1]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	Cannot load lap times for first lap from Ergast. Timing data is not available for this session.
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 19 drivers: ['55', '16', '4', '81', '11', '14', '18', '22', '27', '20', '23', '3', '10', '77', '24', '31', '63', '44', '1']
